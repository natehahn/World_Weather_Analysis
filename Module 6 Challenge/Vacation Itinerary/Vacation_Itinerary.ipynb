# %% [markdown]
# # Deliverable 3. Create a Travel Itinerary Map
#
# ----
#
# 1. Create a folder called `Vacation_Itinerary` to store all the files for this deliverable.
#
# 2. Download the `Vacation_Itinerary_starter_code.ipynb` file into your `Vacation_Itinerary` folder and rename it `Vacation_Itinerary.ipynb`.
#
# 3. Make sure the initial dependencies and the Geoapify API key are imported.
#
# 4. From your `Vacation_Search` folder from Deliverable 2, import the `WeatherPy_vacation.csv` file as a DataFrame named `vacation_df`.
#
# 5. Use GeoViews to create a map that shows all the cities in the `vacation_df` DataFrame. Configure the map as follows:
#
#     * The point's size should be the maximum temperature for the city
#
#     * The point's color should be the city's name
#
#     * Use the `hover_cols` parameter to the the "Hotel Name", "Country", and "Current Description" columns to each point as additional information.
#
# 6. From the map, *choose four cities* that a customer might want to visit. They should be close together and in the same country. Use the `loc` method to create separate DataFrames for each city on the travel route.
#
#     > **Hint:** You will start and end the route in the same city, so the `vacation_start` and `vacation_end` DataFrames will be in the same city.
#
# 7. Use the Pandas `concat` function to merge the DataFrame from each city in the itinerary to create a new DataFrame named `itinerary_df` to store the itinerary details.
#
# 8. Use the Pandas `copy` function to create a new DataFrame named `waypoints_df` to store the longitude and latitude for each city in `itinerary_df`.
#
#     > **Hint:** You'll use this DataFrame to create a map using GeoViews, so recall that the first column should be the longitude, and the second the latitude.
#
# 9. Use GeoViews to create a map that shows the four cities in the itinerary.
#
# 10. Next, you'll use the Geoapify Routing API to find a route between the cities in the itinerary. Review the code that sets the initial parameters and fetches the coordinates from each city to define the `waypoints` parameter by using a `for` loop.
#
#     > **Hint:** You can note that the `mode` parameter is set to `drive`, you can play around with other modes as it's shown in [the "Travel modes" table](https://apidocs.geoapify.com/docs/routing/#api) in the Geoapify Routing API documentation.
#
# 11. Use the Geoapify Routing API to retrieve the route's directions for your itinerary.
#
# 12. From the JSON response, store the route's legs coordinates in a variable called `legs`.
#
# 13. Loop through the route legs coordinates to fetch the latitude and longitude for each step. Store the latitude and longitude values into two Python lists named `longitude` and `latitude`.
#
# 14. Use the `longitude` and `latitude` Python lists to create a new DataFrame named `route_df`.
#
# 15. Use the GeoViews `Path` function to configure a line plot by using `route_df`. Set a custom color and width for the line that may contrast with the map.
#
# 16. Use the asterisk operator to display a composed plot that shows the itinerary's route over the map containing the cities.
#
# 17. Save your map to the `Vacation_Itinerary` folder as `WeatherPy_travel_map.png`.
#
# ---

# %% [markdown]
# ## Make sure the initial dependencies and the Geoapify API key are imported

# %%
# Dependencies and Setup
import geoviews as gv
import hvplot.pandas
import hvplot
import pandas as pd
import requests
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From your `Vacation_Search` folder from Deliverable 2, import the `WeatherPy_vacation.csv` file as a DataFrame named `vacation_df`

# %%
# Read the WeatherPy_vacation.csv into a DataFrame
vacation_search_data_to_load = ("../Vacation Search/WeatherPy_Vacation.csv")
vacation_df = pd.read_csv(vacation_search_data_to_load)

# Display sample data
vacation_df.head(5)
# Out:
#    City_ID      City Country  Max Temp Current Conditions      Lat       Lng  \
# 0        0     Kapaa      US     80.58          clear sky  22.0752 -159.3190
# 1        1  Havelock      US     66.94          clear sky  34.8791  -76.9013
# 2        2     Tabou      CI     78.10   scattered clouds   4.4230   -7.3528
# 3        3    Hobart      AU     55.22   scattered clouds -42.8794  147.3294
# 4        7   Rikitea      PF     72.28    overcast clouds -23.1203 -134.9692
#
#                           Hotel Name
# 0                    Pono Kai Resort
# 1        Quality Inn Havelock Hwy 70
# 2                    hôtel le rochet
# 3  The Old Woolstore Apartment Motel
# 4               Chez Bianca & Benoit

# %% [markdown]
# ## Use GeoViews to create a map that shows all the cities in the `vacation_df` DataFrame. Configure the map as follows:
#
# * The point's size should be the maximum temperature for the city
#
# * The point's color should be the city's name
#
# * Use the `hover_cols` parameter to the the "Hotel Name", "Country", and "Current Description" columns to each point as additional information.

# %%
# Configure the map
map_plot = vacation_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = (["City", "Country", "Current Conditions"])
)

# Display the map plot
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Country,Current Conditions)

# %% [markdown]
# ## From the map, *choose four cities* that a customer might want to visit. They should be close together and in the same country. Use the `loc` method to create separate DataFrames for each city on the travel route.

# %%
# Create DataFrames for each city by filtering the 'vacation_df' using the loc method
vacation_start = vacation_df.loc[vacation_df["City"] == "Cape Town"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Cape Town"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Hermanus"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Bredasdorp"]
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Port Elizabeth"]

# %% [markdown]
# ## Use the Pandas `concat` function to merge the DataFrame from each city in the itinerary to create a new DataFrame named `itinerary_df` to store the itinerary details

# %%
# Use the Pandas concat function to create a new DataFrame to store the itinerary details.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3, vacation_end], axis=0)

# Display sample data
itinerary_df
# Out:
#     City_ID            City Country  Max Temp Current Conditions      Lat  \
# 32       84       Cape Town      ZA     66.11          clear sky -33.9258
# 18       37        Hermanus      ZA     65.80         few clouds -34.4187
# 21       47      Bredasdorp      ZA     64.78          clear sky -34.5322
# 75      194  Port Elizabeth      ZA     73.09          clear sky -33.9180
# 32       84       Cape Town      ZA     66.11          clear sky -33.9258
#
#         Lng        Hotel Name
# 32  18.4232   Townhouse Hotel
# 18  19.2345  Aloe guest house
# 21  20.0403    Victoria Hotel
# 75  25.5701   Waterford Hotel
# 32  18.4232   Townhouse Hotel

# %% [markdown]
# ## Use the Pandas `copy` function to create a new DataFrame named `waypoints_df` to store the longitude and latitude for each city in `itinerary_df`

# %%
# Create a Pandas DataFrame to store the latitude and longitude for each city in the itineray
waypoints_df = itinerary_df[['City', 'Lng', 'Lat']].copy()

# Display sample data
waypoints_df
# Out:
#               City      Lng      Lat
# 32       Cape Town  18.4232 -33.9258
# 18        Hermanus  19.2345 -34.4187
# 21      Bredasdorp  20.0403 -34.5322
# 75  Port Elizabeth  25.5701 -33.9180
# 32       Cape Town  18.4232 -33.9258

# %% [markdown]
# ## Use GeoViews to create map that shows the four cities in the itinerary

# %%
# Configure the map plot by using the itineraty_df
waypoints_map = itinerary_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = 50,
    legend = 'right',
    color = 'City'
    )

# %%
# Display the route_map
waypoints_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City)

# %% [markdown]
# ## Next, you'll use the Geoapify Routing API to find a route between the cities in the itinerary. Review the code that sets the initial parameters and fetches the coordinates from each city to define the `waypoints` parameter by using a `for` loop

# %%
# Set parameters to trace the route
radius = 5000
params = {
    "mode":"drive",
    "apiKey": geoapify_key,
}

# %%
# Set an empty waypoints String variable
waypoints = ""

# Iterate through the route_df DataFrame to define the waypoints
for index, row in waypoints_df.iterrows():
    waypoints = waypoints + str(row["Lat"]) + "," + str(row["Lng"]) + "|"

# Delete the last character from the string
waypoints = waypoints[:-1]

# Add the waypoints to the params dictionary
params["waypoints"] = waypoints

# Display the params dictionary
params
# Out:
# {'mode': 'drive',
#  'apiKey': 'd2a0f6484aed442b94a8b1de808654b7',
#  'waypoints': '-33.9258,18.4232|-34.4187,19.2345|-34.5322,20.0403|-33.918,25.5701|-33.9258,18.4232'}

# %% [markdown]
# ## Use the Geoapify Routing API to retrieve the route's directions for your itinerary

# %%
# Set up the base URL for the Geoapify Places API.
base_url = "https://api.geoapify.com/v1/routing"

# Make request and retrieve the JSON data by using the params dictionaty
route_response = requests.get(base_url, params=params)

# Convert the API response to JSON format
route_response = route_response.json()
route_response
# Out:
# {'features': [{'type': 'Feature',
#    'properties': {'mode': 'drive',
#     'waypoints': [{'location': [18.4232, -33.9258], 'original_index': 0},
#      {'location': [19.2345, -34.4187], 'original_index': 1},
#      {'location': [20.0403, -34.5322], 'original_index': 2},
#      {'location': [25.5701, -33.918], 'original_index': 3},
#      {'location': [18.4232, -33.9258], 'original_index': 4}],
#     'units': 'metric',
#     'distance': 1561194,
#     'distance_units': 'meters',
#     'time': 56432.263,
#     'legs': [{'distance': 118591,
#       'time': 4637.711,
#       'steps': [{'from_index': 0,
#         'to_index': 3,
#         'distance': 158,
#         'time': 9.492,
#         'instruction': {'text': 'Drive southeast on Caledon Street.'}},
#        {'from_index': 3,
#         'to_index': 24,
#         'distance': 390,
#         'time': 32.097,
#         'instruction': {'text': 'Turn left onto Buitenkant Street/M59. Continue on M59.'}},
#        {'from_index': 24,
#         'to_index': 30,
#         'distance': 494,
#         'time': 34.692,
#         'instruction': {'text': 'Turn right onto Strand Street/R102.'}},
#        {'from_index': 30,
#         'to_index': 121,
#         'distance': 3082,
#         'time': 137.505,
#         'instruction': {'text': 'Take the N2/Nelson Mandela Boulevard ramp toward Somerset West/Muizenberg.'}},
#        {'from_index': 121,
#         'to_index': 407,
#         'distance': 20926,
#         'time': 698.651,
#         'instruction': {'text': 'Keep left to stay on N2.'}},
#        {'from_index': 407,
#         'to_index': 1574,
#         'distance': 62300,
#         'time': 2388.818,
#         'instruction': {'text': 'Keep right to stay on N2.'}},
#        {'from_index': 1574,
#         'to_index': 2073,
#         'distance': 31154,
#         'time': 1315.874,
#         'instruction': {'text': 'Take exit 90 onto R43 toward Kleinmond/Hermanus.'}},
#        {'from_index': 2073,
#         'to_index': 2074,
#         'distance': 21,
#         'time': 5.232,
#         'instruction': {'text': 'Turn left.'}},
#        {'from_index': 2074,
#         'to_index': 2079,
#         'distance': 65,
#         'time': 15.346,
#         'instruction': {'text': 'Turn right.'}},
#        {'from_index': 2079,
#         'to_index': 2079,
#         'distance': 0,
#         'time': 0,
#         'instruction': {'text': 'Your destination is on the right.'}}]},
#      {'distance': 91059,
#       'time': 3356.452,
#       'steps': [{'from_index': 0,
#         'to_index': 5,
#         'distance': 65,
#         'time': 9.416,
#         'instruction': {'text': 'Drive south.'}},
#        {'from_index': 5,
#         'to_index': 6,
#         'distance': 21,
#         'time': 5.672,
#         'instruction': {'text': 'Turn left.'}},
#        {'from_index': 6,
#         'to_index': 16,
#         'distance': 368,
#         'time': 24.273,
#         'instruction': {'text': 'Turn left onto Main Road/R43.'}},
#        {'from_index': 16,
#         'to_index': 18,
#         'distance': 10,
#         'time': 0.609,
#         'instruction': {'text': 'Enter the roundabout and take the 1st exit toward Stanford.'}},
#        {'from_index': 18,
#         'to_index': 50,
#         'distance': 624,
#         'time': 31.523,
#         'instruction': {'text': 'Exit the roundabout toward Stanford.'}},
#        {'from_index': 50,
#         'to_index': 62,
#         'distance': 47,
#         'time': 7.806,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit toward Stanford.'}},
#        {'from_index': 62,
#         'to_index': 75,
#         'distance': 207,
#         'time': 10.042,
#         'instruction': {'text': 'Exit the roundabout toward Stanford.'}},
#        {'from_index': 75,
#         'to_index': 77,
#         'distance': 5,
#         'time': 0.328,
#         'instruction': {'text': 'Enter the roundabout and take the 1st exit toward Stanford.'}},
#        {'from_index': 77,
#         'to_index': 175,
#         'distance': 2946,
#         'time': 179.443,
#         'instruction': {'text': 'Exit the roundabout toward Stanford.'}},
#        {'from_index': 175,
#         'to_index': 180,
#         'distance': 54,
#         'time': 5.46,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit onto 7th Street/R43.'}},
#        {'from_index': 180,
#         'to_index': 456,
#         'distance': 20255,
#         'time': 818.366,
#         'instruction': {'text': 'Exit the roundabout onto 7th Street/R43. Continue on R43.'}},
#        {'from_index': 456,
#         'to_index': 458,
#         'distance': 8,
#         'time': 0.386,
#         'instruction': {'text': 'Enter the roundabout and take the 1st exit onto R326.'}},
#        {'from_index': 458,
#         'to_index': 777,
#         'distance': 23178,
#         'time': 834.964,
#         'instruction': {'text': 'Exit the roundabout onto R326.'}},
#        {'from_index': 777,
#         'to_index': 1304,
#         'distance': 43270,
#         'time': 1428.158,
#         'instruction': {'text': 'Turn right onto R316.'}},
#        {'from_index': 1304,
#         'to_index': 1304,
#         'distance': 0,
#         'time': 0,
#         'instruction': {'text': 'Your destination is on the left.'}}]},
#      {'distance': 602016,
#       'time': 21801.835,
#       'steps': [{'from_index': 0,
#         'to_index': 4,
#         'distance': 191,
#         'time': 11.55,
#         'instruction': {'text': 'Drive southeast on Lang Street/R316/Long Street.'}},
#        {'from_index': 4,
#         'to_index': 486,
#         'distance': 58434,
#         'time': 2164.792,
#         'instruction': {'text': 'Turn left onto All Saints Street/R319. Continue on R319.'}},
#        {'from_index': 486,
#         'to_index': 2433,
#         'distance': 175723,
#         'time': 6057.592,
#         'instruction': {'text': 'Turn right toward N2/Swellendam.'}},
#        {'from_index': 2433,
#         'to_index': 3711,
#         'distance': 51841,
#         'time': 1571.807,
#         'instruction': {'text': 'Take exit 387 onto N2 toward George/Port Elizabeth.'}},
#        {'from_index': 3711,
#         'to_index': 3773,
#         'distance': 1199,
#         'time': 44.849,
#         'instruction': {'text': 'Keep right to stay on N2 toward Knysna.'}},
#        {'from_index': 3773,
#         'to_index': 3804,
#         'distance': 640,
#         'time': 38.423,
#         'instruction': {'text': 'Continue on N2.'}},
#        {'from_index': 3804,
#         'to_index': 3813,
#         'distance': 29,
#         'time': 2.24,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit toward N2/Knysna.'}},
#        {'from_index': 3813,
#         'to_index': 4553,
#         'distance': 10593,
#         'time': 582.939,
#         'instruction': {'text': 'Exit the roundabout toward N2/Knysna.'}},
#        {'from_index': 4553,
#         'to_index': 4568,
#         'distance': 42,
#         'time': 4.061,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit toward N2/Knysna.'}},
#        {'from_index': 4568,
#         'to_index': 5715,
#         'distance': 73996,
#         'time': 3217.053,
#         'instruction': {'text': 'Exit the roundabout toward N2/Knysna.'}},
#        {'from_index': 5715,
#         'to_index': 5724,
#         'distance': 32,
#         'time': 2.35,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit toward N2/Port Elizabeth.'}},
#        {'from_index': 5724,
#         'to_index': 7694,
#         'distance': 227189,
#         'time': 7891.772,
#         'instruction': {'text': 'Exit the roundabout toward N2/Port Elizabeth.'},
#         'toll': True},
#        {'from_index': 7694,
#         'to_index': 7737,
#         'distance': 1536,
#         'time': 124.699,
#         'instruction': {'text': 'Take exit 746 onto M10.'}},
#        {'from_index': 7737,
#         'to_index': 7741,
#         'distance': 93,
#         'time': 20.787,
#         'instruction': {'text': 'Turn right onto Ditchling Street.'}},
#        {'from_index': 7741,
#         'to_index': 7751,
#         'distance': 438,
#         'time': 58.228,
#         'instruction': {'text': 'Turn right onto De Smidt Street.'}},
#        {'from_index': 7751,
#         'to_index': 7752,
#         'distance': 36,
#         'time': 8.687,
#         'instruction': {'text': 'Turn left.'}},
#        {'from_index': 7752,
#         'to_index': 7752,
#         'distance': 0,
#         'time': 0,
#         'instruction': {'text': 'You have arrived at your destination.'}}]},
#      {'distance': 749527,
#       'time': 26636.263,
#       'steps': [{'from_index': 0,
#         'to_index': 1,
#         'distance': 36,
#         'time': 6.48,
#         'instruction': {'text': 'Drive west.'}},
#        {'from_index': 1,
#         'to_index': 11,
#         'distance': 438,
#         'time': 58.105,
#         'instruction': {'text': 'Turn right onto De Smidt Street.'}},
#        {'from_index': 11,
#         'to_index': 14,
#         'distance': 86,
#         'time': 12.683,
#         'instruction': {'text': 'Turn left onto Ditchling Street.'}},
#        {'from_index': 14,
#         'to_index': 47,
#         'distance': 1083,
#         'time': 103.771,
#         'instruction': {'text': 'Turn left onto Case Drive.'}},
#        {'from_index': 47,
#         'to_index': 51,
#         'distance': 131,
#         'time': 11.243,
#         'instruction': {'text': 'Turn left onto Stanford Road/M10.'}},
#        {'from_index': 51,
#         'to_index': 2023,
#         'distance': 227681,
#         'time': 7887.111,
#         'instruction': {'text': 'Turn right to take the N2 ramp toward Humansdorp.'},
#         'toll': True},
#        {'from_index': 2023,
#         'to_index': 2032,
#         'distance': 32,
#         'time': 2.37,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit toward N2/George.'}},
#        {'from_index': 2032,
#         'to_index': 3180,
#         'distance': 74006,
#         'time': 3236.063,
#         'instruction': {'text': 'Exit the roundabout toward N2/George.'}},
#        {'from_index': 3180,
#         'to_index': 3193,
#         'distance': 38,
#         'time': 3.159,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit toward N2/George.'}},
#        {'from_index': 3193,
#         'to_index': 3804,
#         'distance': 10604,
#         'time': 592.875,
#         'instruction': {'text': 'Exit the roundabout toward N2/George.'}},
#        {'from_index': 3804,
#         'to_index': 3812,
#         'distance': 25,
#         'time': 1.727,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit toward N2/George.'}},
#        {'from_index': 3812,
#         'to_index': 3826,
#         'distance': 520,
#         'time': 29.418,
#         'instruction': {'text': 'Exit the roundabout toward N2/George.'}},
#        {'from_index': 3826,
#         'to_index': 6883,
#         'distance': 218555,
#         'time': 7326.2,
#         'instruction': {'text': 'Take exit 437 toward Mossel Bay/Cape Town.'}},
#        {'from_index': 6883,
#         'to_index': 6885,
#         'distance': 91,
#         'time': 4.265,
#         'instruction': {'text': 'Stay straight to take the ramp.'}},
#        {'from_index': 6885,
#         'to_index': 11846,
#         'distance': 214810,
#         'time': 7264.521,
#         'instruction': {'text': 'Keep right to take N2.'}},
#        {'from_index': 11846,
#         'to_index': 11863,
#         'distance': 766,
#         'time': 45.376,
#         'instruction': {'text': 'Take exit 1A onto R102/Strand Street toward Cape Town.'}},
#        {'from_index': 11863,
#         'to_index': 11878,
#         'distance': 234,
#         'time': 18.189,
#         'instruction': {'text': 'Turn left onto Castle Street/M59.'}},
#        {'from_index': 11878,
#         'to_index': 11883,
#         'distance': 208,
#         'time': 19.8,
#         'instruction': {'text': 'Turn right onto Darling Street/M4.'}},
#        {'from_index': 11883,
#         'to_index': 11885,
#         'distance': 129,
#         'time': 9.853,
#         'instruction': {'text': 'Turn left onto Corporation Street.'}},
#        {'from_index': 11885,
#         'to_index': 11890,
#         'distance': 47,
#         'time': 3.044,
#         'instruction': {'text': 'Turn left onto Caledon Street.'}},
#        {'from_index': 11890,
#         'to_index': 11890,
#         'distance': 0,
#         'time': 0,
#         'instruction': {'text': 'Your destination is on the left.'}}]}],
#     'toll': True},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[18.422919, -33.926062],
#       [18.423419, -33.926432],
#       [18.424143, -33.926975],
#       [18.424191, -33.927011],
#       [18.424246, -33.926958],
#       [18.424363, -33.926852],
#       [18.424752, -33.926502],
#       [18.424801, -33.926451],
#       [18.425158, -33.926097],
#       [18.425239, -33.926021],
#       [18.425328, -33.925939],
#       [18.425819, -33.925439],
#       [18.425982, -33.925287],
#       [18.425999, -33.925272],
#       [18.426023, -33.925239],
#       [18.426032, -33.925206],
#       [18.426033, -33.925174],
#       [18.426024, -33.925115],
#       [18.42597, -33.924961],
#       [18.425935, -33.924843],
#       [18.425938, -33.924767],
#       [18.425962, -33.924705],
#       [18.42624, -33.924393],
#       [18.426292, -33.924309],
#       [18.426368, -33.924175],
#       [18.426457, -33.924206],
#       [18.426587, -33.924246],
#       [18.426706, -33.924283],
#       [18.428482, -33.924882],
#       [18.430244, -33.925457],
#       [18.431324, -33.92583],
#       [18.431934, -33.925989],
#       [18.432191, -33.926029],
#       [18.433424, -33.92609],
#       [18.433557, -33.926103],
#       [18.433688, -33.926137],
#       [18.433811, -33.926185],
#       [18.433914, -33.926237],
#       [18.434037, -33.926319],
#       [18.434112, -33.926389],
#       [18.434187, -33.926473],
#       [18.434237, -33.926541],
#       [18.434286, -33.926624],
#       [18.434322, -33.926706],
#       [18.434355, -33.926806],
#       [18.434367, -33.926924],
#       [18.434359, -33.927093],
#       [18.434329, -33.927511],
#       [18.434334, -33.927637],
#       [18.43436, -33.927779],
#       [18.4344, -33.927906],
#       [18.434465, -33.928031],
#       [18.434553, -33.928159],
#       [18.434677, -33.928294],
#       [18.434915, -33.928517],
#       [18.435168, -33.928763],
#       [18.435295, -33.9289],
#       [18.435449, -33.929119],
#       [18.435544, -33.929209],
#       [18.435638, -33.929296],
#       [18.436201, -33.929814],
#       [24.545111, -34.041827],
#       [24.543641, -34.04241],
#       [24.542568, -34.042842],
#       [24.540908, -34.043494],
#       [24.539045, -34.044232],
#       [24.53703, -34.045041],
#       [24.533195, -34.046568],
#       [24.531114, -34.04737],
#       [24.529182, -34.048148],
#       [24.526886, -34.049057],
#       [24.520948, -34.051402],
#       [24.516581, -34.053135],
#       [24.515026, -34.053744],
#       [24.514277, -34.054042],
#       [24.513677, -34.054232],
#       [24.51259, -34.054528],
#       [24.512067, -34.054648],
#       [24.51073, -34.054884],
#       [24.509327, -34.055031],
#       [24.508594, -34.055063],
#       [24.507232, -34.055064],
#       [24.506851, -34.055048],
#       [24.506691, -34.055042],
#       [24.505897, -34.054977],
#       [24.503605, -34.054788],
#       [24.498731, -34.054336],
#       [24.49522, -34.054031],
#       [24.488949, -34.053457],
#       [24.465456, -34.051342],
#       [24.464412, -34.051253],
#       [24.461872, -34.051022],
#       [24.461096, -34.050963],
#       [24.460726, -34.050923],
#       [24.452544, -34.050186],
#       [24.450878, -34.050037],
#       [24.449739, -34.04996],
#       [24.449027, -34.049882],
#       [24.446559, -34.049646],
#       [24.444655, -34.049484],
#       [24.444314, -34.049448],
#       [24.441098, -34.04918],
#       [24.438773, -34.048946],
#       [24.43685, -34.048813],
#       [24.435764, -34.048719],
#       [24.431654, -34.048353],
#       [24.422372, -34.047515],
#       [24.420419, -34.04735],
#       [24.416422, -34.046988],
#       [24.414975, -34.04684],
#       [24.414432, -34.046761],
#       [24.413708, -34.04663],
#       [24.413008, -34.046472],
#       [24.412449, -34.046322],
#       [24.411781, -34.046121],
#       [24.410248, -34.045665],
#       [24.406303, -34.044423],
#       [24.403353, -34.04349],
#       [24.399948, -34.042445],
#       [24.397561, -34.041695],
#       [24.396094, -34.041221],
#       [24.39254, -34.040083],
#       [24.389184, -34.039043],
#       [24.387253, -34.038449],
#       [24.385968, -34.038036],
#       [24.383772, -34.037356],
#       [24.381209, -34.036534],
#       [24.37952, -34.035983],
#       ...]]}}],
#  'properties': {'mode': 'drive',
#   'waypoints': [{'lat': -33.9258, 'lon': 18.4232},
#    {'lat': -34.4187, 'lon': 19.2345},
#    {'lat': -34.5322, 'lon': 20.0403},
#    {'lat': -33.918, 'lon': 25.5701},
#    {'lat': -33.9258, 'lon': 18.4232}],
#   'units': 'metric'},
#  'type': 'FeatureCollection'}

# %%
#Fetch the route's legs coordinates from the JSON reponse
legs = route_response['features'][0]['geometry']['coordinates'][0]
legs1 = route_response['features'][0]['geometry']['coordinates'][1]
legs2 = route_response['features'][0]['geometry']['coordinates'][2]
legs3 = route_response['features'][0]['geometry']['coordinates'][3]
all_legs = legs + legs1 + legs2 + legs3
all_legs
# Out:
# [[18.422919, -33.926062],
#  [18.423419, -33.926432],
#  [18.424143, -33.926975],
#  [18.424191, -33.927011],
#  [18.424246, -33.926958],
#  [18.424363, -33.926852],
#  [18.424752, -33.926502],
#  [18.424801, -33.926451],
#  [18.425158, -33.926097],
#  [18.425239, -33.926021],
#  [18.425328, -33.925939],
#  [18.425819, -33.925439],
#  [18.928454, -34.149119],
#  [18.928449, -34.149177],
#  [18.928449, -34.149229],
#  [18.928445, -34.149288],
#  [18.928448, -34.149331],
#  [18.928451, -34.14937],
#  [18.928452, -34.149384],
#  [18.928452, -34.149408],
#  [18.928456, -34.149439],
#  [18.92846, -34.14947],
#  [18.928468, -34.149511],
#  [18.92848, -34.14956],
#  [18.928501, -34.149619],
#  [18.928515, -34.149658],
#  [18.928539, -34.149729],
#  [18.928571, -34.149819],
#  [18.928697, -34.150112],
#  [18.928774, -34.15029],
#  [18.928836, -34.1504],
#  [18.928895, -34.15049],
#  [18.928963, -34.150594],
#  [18.929019, -34.150705],
#  [18.929109, -34.150777],
#  [18.929208, -34.15086],
#  [18.929318, -34.150934],
#  [18.929437, -34.150997],
#  [18.929563, -34.15105],
#  [18.929695, -34.151091],
#  [18.929832, -34.151119],
#  [18.929972, -34.151136],
#  [18.930113, -34.15114],
#  [18.930254, -34.151131],
#  [18.930393, -34.151109],
#  [18.930525, -34.151075],
#  [18.930653, -34.151032],
#  [18.930777, -34.150982],
#  [18.930896, -34.150923],
#  [18.931009, -34.150857],
#  [18.931639, -34.150458],
#  [18.931741, -34.150392],
#  [18.931847, -34.150329],
#  [18.931957, -34.150272],
#  [18.932071, -34.150219],
#  [18.932188, -34.150171],
#  [18.932307, -34.150129],
#  [18.93243, -34.150092],
#  [18.932554, -34.15006],
#  [18.932681, -34.150034],
#  [18.932808, -34.150013],
#  [18.932937, -34.149998],
#  [18.933067, -34.149988],
#  [18.933197, -34.149985],
#  [18.933328, -34.149987],
#  [18.933458, -34.149994],
#  [18.933587, -34.150008],
#  [18.933715, -34.150027],
#  [18.933842, -34.150052],
#  [18.933967, -34.150082],
#  [18.93409, -34.150117],
#  ...]

# %% [markdown]
# ## Loop through the route legs coordinates to fetch the latitude and longitude for each step. Store the latitude and longitude value into two Python lists names `longitude` and `latitude`

# %%
# Create and empty list to store the longitude of each step
longitude = []

# Create and empty list to store the latitude of step
latitude = []

# Loop through the legs coordinates to fetch the latitude and longitude for each step
for coordinate in all_legs:
    long = coordinate[0]
    lat = coordinate[1]
    
    longitude.append(long)
    latitude.append(lat)
   
print(longitude)
# Out:
# [18.422919, 18.423419, 18.424143, 18.424191, 18.424246, 18.424363, 18.424752, 18.424801, 18.425158, 18.425239, 18.425328, 18.425819, 18.425982, 18.425999, 18.426023, 18.426032, 18.426033, 18.426024, 18.42597, 18.425935, 18.425938, 18.425962, 18.42624, 18.426292, 18.426368, 18.426457, 18.426587, 18.426706, 18.428482, 18.430244, 18.431324, 18.431934, 18.432191, 18.433424, 18.433557, 18.433688, 18.433811, 18.433914, 18.434037, 18.434112, 18.434187, 18.434237, 18.434286, 18.434322, 18.434355, 18.434367, 18.434359, 18.434329, 18.434334, 18.43436, 18.4344, 18.434465, 18.434553, 18.434677, 18.434915, 18.435168, 18.435295, 18.435449, 18.435544, 18.435638, 18.436201, 18.436539, 18.436966, 18.437243, 18.437508, 18.437804, 18.438072, 18.438406, 18.438772, 18.439372, 18.439577, 18.439841, 
.583328, 18.584021, 18.584604, 18.585085, 18.585226, 18.585444, 18.585574, 18.585799, 18.5864, 18.586867, 18.587358, 18.587855, 18.588198, 18.588905, 18.589357, 18.589746, 18.590193, 18.590749, 18.591262, 18.591976, 18.592264, 18.592687, 18.592962, 18.593295, 18.595043, 18.599644, 18.600624, 18.600939, 18.601807, 18.602408, 18.602927, 18.603379, 18.603879, 18.604025, 18.604592, 18.605132, 18.605637, ...

# %% [markdown]
# ## Use the `longitude` and `latitude` Python lists to create a new DataFrame named `route_df`

# %%
# Create an empty DataFrame to store the steps' coordinates
route_df = pd.DataFrame()

# Add the steps' longitude and latitude from each step as columns to the DataFrame
route_df = pd.DataFrame({'Longitude': longitude, 'Latitude': latitude})
# Display sample data
route_df
# Out:
#        Longitude   Latitude
# 0      18.422919 -33.926062
# 1      18.423419 -33.926432
# 2      18.424143 -33.926975
# 3      18.424191 -33.927011
# 4      18.424246 -33.926958
# ...          ...        ...
# 23024  18.422668 -33.925761
# 23025  18.422662 -33.925805
# 23026  18.422668 -33.925848
# 23027  18.422685 -33.925889
# 23028  18.422919 -33.926062
#
# [23029 rows x 2 columns]

# %% [markdown]
# ##  Use the GeoViews `Path` function to configure a line plot by using `route_df`. Set a custom color and width for the line that may contrast with the map

# %%
from cartopy import crs
from geoviews import opts
import geoviews.tile_sources as gts
from bokeh.models import ColumnDataSource

# Configure the route path by using the GeoViews' Path function

# route_path = pd.DataFrame(route_df)
route_path = gv.Path(route_df).opts(width=700, height=450, color='red')

# %%
# Display a composed plot by using the route_map and route_path objects
# Configure the map
route_map = waypoints_map * route_path
# Display the map plot
hvplot.save(route_map, 'WeatherPy_Travel_Map.png')
route_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City)
#    .Path.I   :Path   [Longitude,Latitude]

# %%
# Out:
# Collecting selenium
#   Downloading selenium-4.6.1-py3-none-any.whl (6.0 MB)
#      ---------------------------------------- 6.0/6.0 MB 34.9 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\nathan\anaconda3\envs\pythondata\lib\site-packages (from selenium) (1.26.12)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\nathan\anaconda3\envs\pythondata\lib\site-packages (from selenium) (2022.9.24)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      ------------------------------------- 384.9/384.9 kB 23.4 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\nathan\anaconda3\envs\pythondata\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\nathan\anaconda3\envs\pythondata\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.0.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: sniffio in c:\users\nathan\anaconda3\envs\pythondata\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\nathan\anaconda3\envs\pythondata\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: idna in c:\users\nathan\anaconda3\envs\pythondata\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\nathan\anaconda3\envs\pythondata\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\nathan\anaconda3\envs\pythondata\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Installing collected packages: outcome, h11, exceptiongroup, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 exceptiongroup-1.0.4 h11-0.14.0 outcome-1.2.0 selenium-4.6.1 trio-0.22.0 trio-websocket-0.9.2 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.
